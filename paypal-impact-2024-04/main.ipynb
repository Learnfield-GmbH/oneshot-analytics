# %% [markdown]
# This notebook investigates the financial impact of https://skoove.atlassian.net/wiki/spaces/DEV/pages/3755933700/Incident+postmortem+Paypal+2024-04-17

# %%
import pandas as pd
# Don't truncate output
pd.set_option('display.max_columns', None)

# %%
# Exported from https://dashboard.stripe.com/payments
df_src = pd.read_csv('data/stripe_payments_2024-04-08_2024-05-06.csv', quotechar='"', skipinitialspace=True)
# Column names have leading/trailing spaces -> strip them
df_src.columns = df_src.columns.str.strip()

# %%
df_src.head()
# Out:
#                             id   Created date (UTC) Amount Amount Refunded  \
# 0  ch_3PDVunGXe0XeY11p1UWZqo8n  2024-05-06 18:05:29  59,99            0,00
# 1  ch_3PBBe6GXe0XeY11p2uiwOdqJ  2024-05-06 18:02:49  39,99            0,00
# 2  py_3PDVkfGXe0XeY11p1ng1Z3gJ  2024-05-06 17:55:05  59,99            0,00
# 3  ch_3PBEKbGXe0XeY11p2ZtBjQs1  2024-05-06 17:54:49  39,99            0,00
# 4  py_3PDViLGXe0XeY11p1ZmHnTaK  2024-05-06 17:52:38   4,95            0,00
#
#   Currency Captured Converted Amount Converted Amount Refunded  \
# 0      usd    False            59,99                      0,00
# 1      eur    False            39,99                      0,00
# 2      eur     True            59,99                      0,00
# 3      eur    False            39,99                      0,00
# 4      eur     True             4,95                      0,00
#
#   Converted Currency            Description   Fee Is Link  Mode  \
# 0                usd  Invoice ED065010-0003  0,00   False  Live
# 1                eur  Invoice C23EF8F3-0011  0,00   False  Live
# 2                eur  Invoice 03CB504D-0002  2,40   False  Live
# 3                eur  Invoice 76972B49-0016  0,00   False  Live
# 4                eur  Invoice C97B8394-0056  0,00   False  Live
#
#               PaymentIntent ID Payment Source Type Refunded date (UTC)  \
# 0  pi_3PDVunGXe0XeY11p1eTJLnLo                card                 NaN
# 1  pi_3PBBe6GXe0XeY11p2gr4LpDS                card                 NaN
# 2  pi_3PDVkfGXe0XeY11p1qkDDya2              paypal                 NaN
# 3  pi_3PBEKbGXe0XeY11p2rHMtmx2                card                 NaN
# 4  pi_3PDViLGXe0XeY11p1ljpqxEB          sepa_debit                 NaN
#
#   Statement Descriptor   Status  \
# 0               SKOOVE   Failed
# 1               SKOOVE   Failed
# 2                  NaN     Paid
# 3               SKOOVE   Failed
# 4                  NaN  Pending
#
#                                       Seller Message Taxes On Fee  \
# 0  The bank returned the decline code `insufficie...         0,00
# 1  The bank returned the decline code `insufficie...         0,00
# 2                                  Payment complete.         0,00
# 3  The bank returned the decline code `try_again_...         0,00
# 4                                  Payment complete.         0,00
#
#    Interchange Costs  Merchant Service Charge                        Card ID  \
# 0                NaN                      NaN  card_1O9WDgGXe0XeY11pE5kKHzwi
# 1                NaN                      NaN  card_1JqBZbGXe0XeY11p5rUXPZRc
# 2                NaN                      NaN                            NaN
# 3                NaN                      NaN  card_1HAuvlGXe0XeY11pwK2zE0XW
# 4                NaN                      NaN                            NaN
#
#             Card Name Card Address Line1 Card Address Line2 Card Address City  \
# 0      John M Nielsen                NaN                NaN               NaN
# 1       Samu Hokkanen                NaN                NaN               NaN
# 2                 NaN                NaN                NaN               NaN
# 3  Gian Pietro Severi                NaN                NaN               NaN
# 4                 NaN                NaN                NaN               NaN
#
#   Card Address State Card Address Country Card Address Zip  \
# 0                NaN                  NaN              NaN
# 1                NaN                  NaN              NaN
# 2                NaN                  NaN              NaN
# 3                NaN                  NaN              NaN
# 4                NaN                  NaN              NaN
#
#   Card AVS Line1 Status Card AVS Zip Status  Card Brand Card CVC Status  \
# 0                   NaN                 NaN  MasterCard             NaN
# 1                   NaN                 NaN        Visa             NaN
# 2                   NaN                 NaN         NaN             NaN
# 3                   NaN                 NaN  MasterCard             NaN
# 4                   NaN                 NaN         NaN             NaN
#
#    Card Exp Month  Card Exp Year  Card Fingerprint Card Funding  \
# 0            11.0         2025.0  I76fyZwUcM9ChY1q       credit
# 1            10.0         2025.0  xlpq40UwUD5MJxqp       credit
# 2             NaN            NaN               NaN          NaN
# 3             6.0         2021.0  Tr34yJ7QdN8HO9wU      prepaid
# 4             NaN            NaN               NaN          NaN
#
#   Card Issue Country  Card Last4 Card Tokenization Method         Customer ID  \
# 0                 US       274.0                      NaN  cus_OxR5yAA1BB0NnE
# 1                 FI      9213.0                      NaN  cus_KVBxW1UP6FVSon
# 2                NaN         NaN                      NaN  cus_PV9Epbowcsj35v
# 3                 IT      8876.0                      NaN  cus_HkPlNBA8P716mM
# 4                NaN         NaN                      NaN  cus_FiiQdgYrpTYhUD
#
#   Customer Description            Customer Email  Customer Phone  \
# 0                  NaN      john4omega@yahoo.com             NaN
# 1                  NaN   samu.hokkanen@gmail.com             NaN
# 2                  NaN  massimofinotto@gmail.com             NaN
# 3                  NaN     katyandra49@gmail.com             NaN
# 4                  NaN          nsol@mailbox.org             NaN
#
#    Shipping Name  Shipping Address Line1  Shipping Address Line2  \
# 0            NaN                     NaN                     NaN
# 1            NaN                     NaN                     NaN
# 2            NaN                     NaN                     NaN
# 3            NaN                     NaN                     NaN
# 4            NaN                     NaN                     NaN
#
#    Shipping Address City  Shipping Address State  Shipping Address Country  \
# 0                    NaN                     NaN                       NaN
# 1                    NaN                     NaN                       NaN
# 2                    NaN                     NaN                       NaN
# 3                    NaN                     NaN                       NaN
# 4                    NaN                     NaN                       NaN
#
#    Shipping Address Postal Code Disputed Amount Dispute Date (UTC)  \
# 0                           NaN             NaN                NaN
# 1                           NaN             NaN                NaN
# 2                           NaN             NaN                NaN
# 3                           NaN             NaN                NaN
# 4                           NaN             NaN                NaN
#
#   Dispute Evidence Due (UTC) Dispute Reason Dispute Status  \
# 0                        NaN            NaN            NaN
# 1                        NaN            NaN            NaN
# 2                        NaN            NaN            NaN
# 3                        NaN            NaN            NaN
# 4                        NaN            NaN            NaN
#
#                     Invoice ID Invoice Number Checkout Session ID  \
# 0  in_1PDUy9GXe0XeY11pTODEvZ0R  ED065010-0003                 NaN
# 1  in_1PBAhdGXe0XeY11pT3uUMZJR  C23EF8F3-0011                 NaN
# 2  in_1PDUnKGXe0XeY11pTuahnxDS  03CB504D-0002                 NaN
# 3  in_1PBDOLGXe0XeY11pJJsJ04ho  76972B49-0016                 NaN
# 4  in_1PDUlNGXe0XeY11pArkFhwwI  C97B8394-0056                 NaN
#
#    Checkout Custom Field 1 Key  Checkout Custom Field 1 Value  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
#
#    Checkout Custom Field 2 Key  Checkout Custom Field 2 Value  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
#
#    Checkout Custom Field 3 Key  Checkout Custom Field 3 Value  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
#
#   Checkout Line Item Summary  Checkout Promotional Consent  \
# 0                        NaN                           NaN
# 1                        NaN                           NaN
# 2                        NaN                           NaN
# 3                        NaN                           NaN
# 4                        NaN                           NaN
#
#    Checkout Terms of Service Consent Client Reference ID  Payment Link ID  \
# 0                                NaN                 NaN              NaN
# 1                                NaN                 NaN              NaN
# 2                                NaN                 NaN              NaN
# 3                                NaN                 NaN              NaN
# 4                                NaN                 NaN              NaN
#
#    UTM Campaign  UTM Content  UTM Medium  UTM Source  UTM Term  \
# 0           NaN          NaN         NaN         NaN       NaN
# 1           NaN          NaN         NaN         NaN       NaN
# 2           NaN          NaN         NaN         NaN       NaN
# 3           NaN          NaN         NaN         NaN       NaN
# 4           NaN          NaN         NaN         NaN       NaN
#
#    Application Fee Application ID  Destination Transfer  Transfer Group  \
# 0              NaN            NaN          NaN      NaN             NaN
# 1              NaN            NaN          NaN      NaN             NaN
# 2              NaN            NaN          NaN      NaN             NaN
# 3              NaN            NaN          NaN      NaN             NaN
# 4              NaN            NaN          NaN      NaN             NaN
#
#    user_id (metadata) source (metadata) Purchaser Email (metadata)  \
# 0                 NaN               NaN                        NaN
# 1                 NaN               NaN                        NaN
# 2                 NaN               NaN                        NaN
# 3                 NaN               NaN                        NaN
# 4                 NaN               NaN                        NaN
#
#   Gift Up Order Id (metadata) Recipient Name (metadata)  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
#
#   Gift Card Code (metadata) Gift Card Link (metadata)  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#   Recipient Email (metadata) Purchaser Name (metadata)
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN

# %%
df = df_src[['id', 'Created date (UTC)', 'Amount', 'Amount Refunded', 'Currency', 'Description', 'Status', 'Customer Email', 'Payment Source Type', 'Seller Message']]

# Data cleaning (loc is used to change in place, without triggering SettingWithCopyWarning)
df.loc[:, 'Created date (UTC)'] = pd.to_datetime(df['Created date (UTC)'])
df.loc[:, 'Amount'] = pd.to_numeric(df['Amount'].str.replace(',', '.'), errors='coerce')

# %%
df_failed_paypal_during_incident = df[
	(df['Created date (UTC)'] >= pd.to_datetime('2024-04-08'))
	& (df['Created date (UTC)'] <= pd.to_datetime('2024-04-24'))
	& (df['Status'] == 'Failed')
	& (df['Payment Source Type'] == 'paypal')
]

# %%
df_succeeded_after_incident = df[
	(df['Created date (UTC)'] >= pd.to_datetime('2024-04-24'))
	& (df['Status'] == 'Paid')
]

# %% [markdown]
# 2 Customers who were affected by the PayPal outage have a successful payment after the incident was over:

# %%
df_healed = df_succeeded_after_incident[
	df_succeeded_after_incident['Customer Email'].isin(df_failed_paypal_during_incident['Customer Email'])]
df_healed
# Out:
#                                id   Created date (UTC) Amount Amount Refunded  \
# 1967  py_3P7f7mGXe0XeY11p0PlCtpN2  2024-04-24 02:42:49  59.99            0,00
# 1973  py_3P6NezGXe0XeY11p1LqfZHdH  2024-04-24 01:51:52  59.99            0,00
#
#      Currency            Description Status                 Customer Email  \
# 1967      usd  Invoice 2A0A9B35-0002   Paid  infobetancoservices@gmail.com
# 1973      usd  Invoice 861DA2F8-0002   Paid    ben.peter.leonard@gmail.com
#
#      Payment Source Type     Seller Message
# 1967              paypal  Payment complete.
# 1973              paypal  Payment complete.

# %% [markdown]
# 432 failed payments:

# %%
df_permanently_failed = df_failed_paypal_during_incident[
	~df_failed_paypal_during_incident['Customer Email'].isin(df_healed['Customer Email'])]
df_permanently_failed.shape
# Out:
# (432, 10)

# %% [markdown]
# Payments were repeated up to 5 times:

# %%
df_permanently_failed.groupby('Customer Email').size().sort_values(ascending=False).head()
# Out:
# Customer Email
# 12504mee@gmail.com             5
# info@tretbar.net               5
# markusanthonyjr26@gmail.com    5
# madisoncranford4@gmail.com     5
# luna1stars2@yahoo.com          5
# dtype: int64

# %%
df_permanently_failed_unique_emails = df_permanently_failed.drop_duplicates(subset=('Customer Email', 'Currency', 'Amount'))

# %% [markdown]
# # Total volume of failed payments, by currency

# %%
df_permanently_failed_unique_emails.groupby('Currency')['Amount'].sum().to_frame()
# Out:
#            Amount
# Currency
# eur       2489.63
# gbp        249.95
# usd       4529.31

# %% [markdown]
# # Failed purchase attempts, by offer (currency and amount):

# %%
df_permanently_failed_unique_emails.groupby(['Currency', 'Amount'])['Amount'].count().to_frame()
# Out:
#                  Amount
# Currency Amount
# eur      29.99        1
#          59.99       32
#          89.99        1
#          149.99       3
# gbp      49.99        5
# usd      29.99        2
#          59.99       62
#          149.99       5

# %% [markdown]
# # Questions
# - What kinds of subscriptions do these failed transactions refer to? Which of these were failed renewals?
# - Did any of the failed purchase potential customers get in touch? Did they pay some other way, outside of Stripe?

# %% [markdown]
# All emails of users with failed PayPal payments:

# %%
for email in df_permanently_failed_unique_emails['Customer Email']:
	print(email)
# Out:
# dagjmg01930@gmail.com
# rayvon.garvin@hotmail.com
# theo0329@yahoo.com
# markusanthonyjr26@gmail.com
# jarodlutzz@gmail.com
# juliengrabowski@googlemail.com
